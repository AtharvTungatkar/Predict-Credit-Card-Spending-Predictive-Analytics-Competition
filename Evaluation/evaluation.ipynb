# %%
import os
os.chdir('../')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import root_mean_squared_error

data = pd.read_csv('Datasets/analysis_data.csv')
y=data['monthly_spend']

# %%
name=input('Write the name of the submission you want to evaluate here')
y_hat=pd.read_csv(f'Evaluation/{name}.csv')
root_mean_squared_error(y,y_hat)
# Out:
# 261.87413168602234
